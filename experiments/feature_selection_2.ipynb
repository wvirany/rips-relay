# %%
import subprocess
import os
print('Current conda environment:', os.environ['CONDA_DEFAULT_ENV'])
os.environ['TOKENIZERS_PARALLELISM'] = "false"

cwd = os.getcwd()
print(cwd)

import warnings
warnings.filterwarnings('ignore')

import random
random.seed(42)
# Out:
# Current conda environment: reinvent
# /home/fts_g_ucla_edu/Projects/rips-relay/experiments

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
sns.set(rc = {'figure.figsize':(15,8)})

from crem.crem import grow_mol, mutate_mol
crem_db = '../crem_db/crem_db2.5.db'

import mols2grid

from rdkit import Chem
from rdkit.Chem import AllChem, rdFingerprintGenerator, CanonSmiles, Draw, MolFromSmiles, PandasTools
from rdkit.Chem.rdmolops import RDKFingerprint
from rdkit import DataStructs
from rdkit.Chem.rdFMCS import FindMCS
from rdkit.DataStructs.cDataStructs import BulkTanimotoSimilarity
import useful_rdkit_utils as uru

import prolif as plf

import safe as sf
import datamol as dm

import mols2grid

from moleval.metrics.metrics import GetMetrics

from sklearn.preprocessing import StandardScaler, OneHotEncoder, OrdinalEncoder
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, classification_report
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

import torch

from coati.generative.coati_purifications import embed_smiles
from coati.models.io.coati import load_e3gnn_smiles_clip_e2e
from coati.models.simple_coati2.io import load_coati2
# Out:
# Failed to find the pandas get_adjustment() function to patch
# Failed to patch pandas - PandasTools will have limited functionality

# %%
pdb = '2zdt'

# %%
initial_mol = Chem.MolFromMolFile(f"data/docking/{pdb}_ligand.sdf")
initial = Chem.MolToSmiles(initial_mol)

initial_mol

# %%
initial
# Out:
# 'CCC(=O)c1c(-c2ccccc2)c2cc(Cl)ccc2c(=O)n1Cc1ccc(C(=O)[O-])cc1'

# %% [markdown]
# ### Interaction fingerprint for reference molecule

# %%
REF_MOL_FILEPATH = f"data/docking/{pdb}_ligand.sdf"
PDB_FILEPATH = f"data/docking/{pdb}.pdb"

fp = plf.Fingerprint()

mol = Chem.MolFromPDBFile(PDB_FILEPATH, removeHs=False)
prot = plf.Molecule(mol)
suppl = plf.sdf_supplier(REF_MOL_FILEPATH)
fp.run_from_iterable(suppl, prot, progress=True)
df_ifp = fp.to_dataframe()
df_ifp.columns = df_ifp.columns.droplevel(0)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
df_ifp
# Out:
# protein        LYS68.A                        ILE70.A    GLY71.A     VAL78.A  \
# interaction HBAcceptor Anionic VdWContact Hydrophobic VdWContact Hydrophobic
# Frame
# 0                 True    True       True        True       True        True
#
# protein                    ALA91.A               ILE124.A  ...   ASN152.A  \
# interaction VdWContact Hydrophobic VdWContact Hydrophobic  ... VdWContact
# Frame                                                      ...
# 0                 True        True       True        True  ...       True
#
# protein       SER193.A    VAL196.A               LEU206.A    46C901.A  \
# interaction VdWContact Hydrophobic VdWContact Hydrophobic Hydrophobic
# Frame
# 0                 True        True       True        True        True
#
# protein                             HOH986.A
# interaction PiStacking VdWContact HBAcceptor VdWContact
# Frame
# 0                 True       True       True       True
#
# [1 rows x 28 columns]

# %%
def ifp_similarity(ref_mol_ifp, df_ifp, df):
    ## Rename columns
    df_ifp.columns = [' '.join(col) if isinstance(col, tuple) else col for col in df_ifp.columns]
    ref_mol_ifp.columns = [' '.join(col) if isinstance(col, tuple) else col for col in ref_mol_ifp.columns]
    

    intersections = []
    weighted_intersections = []

    #iterate over the rows
    for index, row in df_ifp.iterrows():
        count=0
        weighted_count = 0
        #iterate over all columns
        for col_name in df_ifp.columns:
            if col_name in ref_mol_ifp.columns and df_ifp[col_name][index]==ref_mol_ifp[col_name][0] and 'VdWContact' in col_name:
                count += 1
                weighted_count += 1
            elif col_name in ref_mol_ifp.columns and df_ifp[col_name][index]==ref_mol_ifp[col_name][0] and 'Hydrophobic' in col_name:
                count += 1
                weighted_count += 2
            elif col_name in ref_mol_ifp.columns and df_ifp[col_name][index]==ref_mol_ifp[col_name][0] and 'HBAcceptor' in col_name:
                count += 1
                weighted_count += 3
            elif col_name in ref_mol_ifp.columns and df_ifp[col_name][index]==ref_mol_ifp[col_name][0] and 'Anionic' in col_name or 'Cationic' in col_name:
                count += 1
                weighted_count += 4
        
        intersections.append(count)
        weighted_intersections.append(weighted_count)
                
    df['IFP Intersection'] = intersections
    df['Weighted IFP Intersection'] = weighted_intersections

    return df

# %%
def compute_features(df, ifp):

    cols = ifp.columns

    num_cols = len(ifp.columns)

    data = {'mol_id' : [],
            'num_interactions' : [],
            'weighted_interactions' : [],
            'num_VdW' : [],
            'num_hydrophobic' : [],
            'num_HBAcceptor' : [],
            'num_ionic' : []}

    for index, row in ifp.iterrows():

        weighted_interactions = 0
        num_VdW = 0
        num_hydrophobic = 0
        num_HBAcceptor = 0
        num_ionic = 0
        
        data['mol_id'].append(row['ID'][0])
        data['num_interactions'].append(row[:-1].sum())

        for value in cols:
            
            if value[1] == 'VdWContact':
                weighted_interactions += 1 * row[value]
                num_VdW += 1 * row[value]
            elif value[1] == 'Hydrophobic':
                weighted_interactions += 2 * row[value]
                num_hydrophobic += 1 * row[value]
            elif value[1] == 'HBAcceptor':
                weighted_interactions += 3 * row[value]
                num_HBAcceptor += 1 * row[value]
            elif value[1] == 'Anionic' or value[1] == 'Cationic':
                weighted_interactions += 4 * row[value]
                num_ionic += 1 * row[value]

        data['weighted_interactions'].append(weighted_interactions)
        data['num_VdW'].append(num_VdW)
        data['num_hydrophobic'].append(num_hydrophobic)
        data['num_HBAcceptor'].append(num_HBAcceptor)
        data['num_ionic'].append(num_ionic)

            

    features = pd.DataFrame(data)

    df = df.merge(features[['mol_id', 'num_interactions', 'weighted_interactions', 'num_VdW', 'num_hydrophobic', 'num_HBAcceptor', 'num_ionic']], left_on='ID', right_on='mol_id', how='left')

    df = df.drop(['mol_id'], axis=1).sort_values(['Docking score'], ascending=True)

    df.dropna(axis=0, subset=['Docking score'], inplace=True)
    df['num_interactions'].fillna(0, inplace=True)
    df['weighted_interactions'].fillna(0, inplace=True)

    return df

# %%
def visualize_fingerprint(ifp):

    sns.set(rc = {'figure.figsize':(15,8)})
    ax = sns.heatmap(ifp,cmap=sns.cm.rocket_r)
    ax.set_ylabel("Molecule")
    ax.set_xlabel("Protein Interaction")

    return ax

# %%
def remove_odd_rings(df):
    ring_system_lookup = uru.RingSystemLookup.default()
    df['ring_systems'] = df.SMILES.apply(ring_system_lookup.process_smiles)
    df[['min_ring','min_freq']] = df.ring_systems.apply(uru.get_min_ring_frequency).to_list()
    bad_rings = df.query('min_freq <= 100').copy()
    df = df.query('min_freq > 100').copy()
    return df, bad_rings

# %%
models = ['reinvent', 'crem', 'coati', 'safe']
ifps = []
model_df = pd.DataFrame()

# %%
for model in models:

    DF_FILEPATH = f'data/{model}_dataframe.csv'
    IFP_FILEPATH = f'data/{model}_ifp.csv'

    temp_df = pd.read_csv(DF_FILEPATH, index_col=0)
    ifp = pd.read_csv(IFP_FILEPATH, header=[0, 1], index_col=0)

    if model == 'reinvent':
        temp_df['Model'] = model

    temp_df = compute_features(temp_df, ifp)
    temp_df = ifp_similarity(df_ifp, ifp, temp_df)

    model_df = pd.concat((model_df, temp_df))

# %%
model_df.drop(['Input_SMILES', 'Tanimoto', 'Prior'], axis=1, inplace=True)

# %%
model_df, bad_rings = remove_odd_rings(model_df)

# %%
model_df
# Out:
#                                                 SMILES       ID  \
# 121  CCOC(=O)c1c(-c2ccccc2)c2cc(C(F)(F)F)ccc2c(=O)n...  MOL0121
# 196  COCC(=O)/C=C/c1c(-c2ccccc2)c2cc(Cl)ccc2c(=O)n1...  MOL0196
# 150  CCC(=O)c1ccc(Cn2c(C(=O)OC)c(-c3ccccc3)c3cc(Cl)...  MOL0150
# 99   COc1ccc2c(=O)n(Cc3ccc(C(=O)O)cc3)c(/C=C/C(=O)O...  MOL0099
# 127  CC(=O)c1c(-c2ccccc2)c2cc(C(F)(F)F)ccc2c(=O)n1C...  MOL0127
# ..                                                 ...      ...
# 116  O=C([O-])c1ccc(C(c2cccnc2)n2c(C(=O)CCc3nccs3)c...  MOL0116
# 52   O=C([O-])c1ccc(C(N2CCCCCC2)n2c(C(=O)CCc3ccccc3...  MOL0052
# 127  O=C([O-])c1ccc(C(c2ccoc2)n2c(C(=O)CCc3nn[nH]n3...  MOL0127
# 160  O=C([O-])c1ccc(C(c2ncco2)n2c(C(=O)CCc3cccs3)c(...  MOL0160
# 187  O=C([O-])c1ccc(C(OCC(F)(F)F)n2c(C(=O)CCc3cnc[n...  MOL0187
#
#      Docking score       rmsd     Model  num_interactions  \
# 121     -16.624857   3.737471  reinvent              27.0
# 196     -16.540930   3.676144  reinvent              32.0
# 150     -16.529593   5.569642  reinvent              25.0
# 99      -16.301600   3.785833  reinvent              29.0
# 127     -16.295380   5.360354  reinvent              27.0
# ..             ...        ...       ...               ...
# 116      -6.331114  27.607474      safe              32.0
# 52       -4.646422  10.012813      safe              33.0
# 127      -4.419723  27.196813      safe              29.0
# 160      -3.819107  28.181917      safe              33.0
# 187      -3.804209  27.503604      safe              30.0
#
#      weighted_interactions  num_VdW  num_hydrophobic  num_HBAcceptor  \
# 121                   45.0     13.0             10.0             4.0
# 196                   48.0     17.0             11.0             3.0
# 150                   40.0     11.0             10.0             3.0
# 99                    45.0     16.0             10.0             3.0
# 127                   42.0     14.0             11.0             2.0
# ..                     ...      ...              ...             ...
# 116                   48.0     17.0             12.0             1.0
# 52                    52.0     18.0             12.0             2.0
# 127                   43.0     16.0             10.0             1.0
# 160                   46.0     22.0             10.0             0.0
# 187                   44.0     17.0             10.0             1.0
#
#      num_ionic  IFP Intersection  Weighted IFP Intersection  \
# 121        0.0                21                         39
# 196        0.0                24                         41
# 150        0.0                20                         36
# 99         0.0                22                         38
# 127        0.0                20                         35
# ..         ...               ...                        ...
# 116        1.0                21                         39
# 52         1.0                23                         42
# 127        1.0                20                         37
# 160        1.0                22                         38
# 187        1.0                22                         40
#
#                                           ring_systems             min_ring  \
# 121  [(O=c1[nH]ccc2ccccc12, 2230), (c1ccccc1, 22600...  O=c1[nH]ccc2ccccc12
# 196  [(O=c1[nH]ccc2ccccc12, 2230), (c1ccccc1, 22600...  O=c1[nH]ccc2ccccc12
# 150  [(O=c1[nH]ccc2ccccc12, 2230), (c1ccccc1, 22600...  O=c1[nH]ccc2ccccc12
# 99   [(O=c1[nH]ccc2ccccc12, 2230), (c1ccccc1, 22600...  O=c1[nH]ccc2ccccc12
# 127  [(O=c1[nH]ccc2ccccc12, 2230), (c1ccccc1, 22600...  O=c1[nH]ccc2ccccc12
# ..                                                 ...                  ...
# 116  [(O=c1[nH]ccc2ccccc12, 2230), (c1cscn1, 61036)...  O=c1[nH]ccc2ccccc12
# 52   [(O=c1[nH]ccc2ccccc12, 2230), (C1CCCNCC1, 6337...  O=c1[nH]ccc2ccccc12
# 127  [(O=c1[nH]ccc2ccccc12, 2230), (c1nn[nH]n1, 206...  O=c1[nH]ccc2ccccc12
# 160  [(O=c1[nH]ccc2ccccc12, 2230), (c1cocn1, 15605)...  O=c1[nH]ccc2ccccc12
# 187  [(O=c1[nH]ccc2ccccc12, 2230), (c1c[nH]cn1, 669...  O=c1[nH]ccc2ccccc12
#
#     min_freq
# 121     2230
# 196     2230
# 150     2230
# 99      2230
# 127     2230
# ..       ...
# 116     2230
# 52      2230
# 127     2230
# 160     2230
# 187     2230
#
# [740 rows x 16 columns]

# %%
bad_rings
# Out:
#                                                 SMILES       ID  \
# 46   CCOc1ccc2c(C(=O)CC)n(Cc3ccc(C(=O)O)cc3)c(=O)c(...  MOL0046
# 90   COc1ccc2c(C(=O)OC(C)C)n(Cc3ccc(C(=O)O)cc3)c(=O...  MOL0090
# 2    CCC(=O)c1c(-c2ccccc2)c2cc(Cl)ccc2c(=O)n1Cc1ccc...  MOL0002
# 125  CCC(=O)C1=C(c2ccccc2)c2cc(Cl)ccc2[NH+]=CN1Cc1c...  MOL0125
# 126  CCC(=O)C1=C(c2ccc(Cl)cc2)C(=O)N1Cc1ccc(C(=O)[O...  MOL0126
# 168  CCC(=O)c1cc2c(Cl)c(-c3ccccc3)sc2c(=O)n1Cc1ccc(...  MOL0168
# 175  CCC(=O)C1=CN(c2ccccc2)c2cc(C(C)(C)C)ccc2N1C(=O...  MOL0175
# 111  CCC(=O)c1c(-c2ccccc2)oc2c(Cl)cc-2n1Cc1ccc(C(=O...  MOL0111
# 51   CC[n+]1c(-c2ccccc2)c2cc(Cl)ccc2c(=O)n(Cc2ccc(C...  MOL0051
# 176  CCc1[nH+]c2c(c(-c3ccccc3[O-])nn2Cc2ccc(C(=O)[O...  MOL0176
# 195  CCC(=O)c1c(-c2ccccc2)c2cc(Cl)ccc2n1CC1=C(C(=O)...  MOL0195
# 30   CC/C([O-])=C1\c2cc(Cl)cc(-c3ccccc3)c2C(=O)N1Cc...  MOL0030
# 170  CCC(=O)C1=C(c2ccccc2)c2cc(Cl)ccc2[NH+]=C([O-])...  MOL0170
# 87   CCC(=C(C=O)c1ccccc1)C1=c2c(=O)c(CC)cn(Cc3ccc(C...  MOL0087
# 24   CCC(=O)c1c(C)n(Cc2ccc(-c3ccccc3)cc2)c2c(Cl)cc[...  MOL0024
# 56   CC[C@@H]1N=C(c2ccccc2)C(=O)c2cc(Cl)ccc2N1Cc1cc...  MOL0056
# 133  CCC(=O)[C@H]1[C@@H](c2ccccc2)c2c(Cl)cc(C(C)=O)...  MOL0133
# 129  CCc1c(-c2ccccc2)n(Cc2ccc(Cl)cc2C(=O)c2ccc(C(=O...  MOL0129
# 62   CC[C@@]1(c2ccccc2)C(=O)c2ccc(Cl)cc2C(=O)N1Cc1c...  MOL0062
# 97   CCC=C(C1=C(Cc2ccc(C(=O)[O-])cc2)C(=O)c2cccn21)...  MOL0097
# 61   CC/C([O-])=C1\c2cc(Cl)cc(-c3ccccc3)c2N1Cc1ccc(...  MOL0061
# 189  O=C([O-])c1[n-]c2c(Cl)cc(-c3ccccc3)cc2c1C[NH+]...  MOL0189
# 52   CC[n+]1c(C(=O)c2ccc(C(=O)[O-])cc2)c(Cl)c2ccccc...  MOL0052
# 145  CCC(=O)c1[nH+]c2ccc(C(=O)[O-])cc2c(=O)n1-c1ccc...  MOL0145
# 14             CCC(=O)C(=C1SCc2ccc(Cl)cc2C1=O)c1ccccc1  MOL0014
# 190  CCC([O-])=C1c2cc(Cl)ccc2C(=O)N1Cc1ccc(C(=O)[O-...  MOL0190
# 13   CCC=C(C(=O)C1(COC(=O)c2ccccc2)CC1)C1=C([O-])C=...  MOL0013
# 10   CCC(=O)C(=C1c2cc(Cl)ccc2C(=O)N1Cc1ccc(C(=O)[O-...  MOL0010
# 96   CCC(=O)C1=CC=C(c2ccccc2)c2cc(Cl)ccc2C(=O)N1Cc1...  MOL0096
# 113  CC[C@@H]1/C(=C(\[O-])c2ccccc2)C(=O)c2cc(Cl)ccc...  MOL0113
# 169  CCC(=O)C(=Cc1c(Cl)cc(-c2ccccc2)c(=O)c2ccccc12)...  MOL0169
# 21   CCC(=O)[C@@]1(c2ccccc2)C(=O)c2ccccc2N1Cc1ccc(C...  MOL0021
# 154  CCC(=O)N1C(=O)C(c2ccccc2)c2cc(Cl)ccc2[NH+]1Cc1...  MOL0154
# 8    CCC(=O)C1=C(c2ccccc2)C(=O)Oc2cccc(Cl)c2N1Cc1cc...  MOL0008
# 83   CCC(=C(c1ccccc1)c1cc(F)cc2c(Cl)cccc2c1=O)c1ccc...  MOL0083
# 75   CCc1c(-c2ccc(C(=O)[O-])cc2)c(=O)c2cccc(Cl)c2n(...  MOL0075
# 167  CC[C@]1(c2ccccc2)[C@@H](Cc2ccc(C(=O)[O-])cc2)O...  MOL0167
# 88   CCC(=O)C(=C1c2cc(Cl)cc(C(=O)[O-])c2CC(=O)N1Cc1...  MOL0088
# 76   CC[C@H]1OC(=O)C(c2ccccc2)=C(c2ccccc2)c2c(Cl)cc...  MOL0076
# 192  CC/C=C1\c2nc([O-])c(-c3ccccc3)n2CC1Cc1ccc(C(=O...  MOL0192
# 198  CCC/C([O-])=C(/c1ccccc1)c1nc2n(Cc3ccc(C(=O)[O-...  MOL0198
# 48   CCC([O-])=C(Cn1c(-c2ccc(Cl)cc2)[nH+]c2ccc(F)cc...  MOL0048
# 180  CCC(=O)C(C(=O)c1ccc([O-])cc1)=C(c1ccccc1)c1cc(...  MOL0180
# 94   CCC(=O)[C@@]1(c2ccccc2)C(=O)c2cccc(Cl)c2N1Cc1c...  MOL0094
# 183  CCC(=O)C1=CN=C(c2ccccc2)c2cc(Cl)ccc2N1Cc1ccc(C...  MOL0183
# 188  CCC(=O)C(=C1C=C(Cl)C(=O)c2ccccc2N1Cc1ccc(C(=O)...  MOL0188
# 71   CCC([O-])c1ccc(-c2ccccc2)c(=O)c2cc(Cl)c-2n1Cc1...  MOL0071
# 23   CCC(=O)C(=CC1=CC=C(c2ccccc2)c2cc(Cl)ccc2N1Cc1c...  MOL0023
# 131  CCC(=O)N1c2c(cc(Cl)cc2-c2ccccc2)C(=O)c2ccccc2N...  MOL0131
# 138  O=C([O-])c1ccc(Cn2c(C(=O)CCNC3=NC=CNC3)c(-c3cc...  MOL0138
# 18   O=C([O-])c1ccc(Cn2c(C(=O)CCNC3=NS(=O)(=O)N=C3)...  MOL0018
# 83   O=C([O-])c1ccc(Cn2c(C(=O)CCN3[C@@H]4CCN[C@H]3C...  MOL0083
#
#      Docking score       rmsd     Model  num_interactions  \
# 46      -10.755634   9.745061  reinvent              31.0
# 90       -9.814790   8.372586  reinvent              30.0
# 2       -14.263374   6.541037      crem              26.0
# 125     -14.674456   7.355187     coati              28.0
# 126     -13.071126   7.871390     coati              26.0
# 168     -12.642220  15.916714     coati              31.0
# 175     -12.339231  13.419985     coati              34.0
# 111     -12.305086   8.101304     coati              25.0
# 51      -11.997536  20.762123     coati              29.0
# 176     -11.835547  12.727678     coati              36.0
# 195     -11.806998   3.752849     coati              20.0
# 30      -11.579596  10.528473     coati              32.0
# 170     -11.456704   7.289153     coati              28.0
# 87      -10.868896  12.839174     coati              30.0
# 24      -10.774113  19.731998     coati              29.0
# 56      -10.653829  11.807473     coati              20.0
# 133     -10.554357  21.742855     coati              25.0
# 129     -10.087529  32.316435     coati              28.0
# 62       -9.932362  15.794207     coati              25.0
# 97       -9.913025  27.304712     coati              26.0
# 61       -9.910788  17.346614     coati              27.0
# 189      -9.754824  20.693550     coati              24.0
# 52       -9.703503  22.968561     coati              29.0
# 145      -9.585447  15.768381     coati              23.0
# 14       -9.489892  16.514360     coati              24.0
# 190      -9.174466  18.251465     coati              19.0
# 13       -8.856135  21.310433     coati              25.0
# 10       -8.243429   8.637742     coati              24.0
# 96       -8.155087  24.191856     coati              26.0
# 113      -8.125884  16.722180     coati              30.0
# 169      -8.039425  25.519413     coati              29.0
# 21       -7.972140  14.584876     coati              29.0
# 154      -7.922272  20.667567     coati              19.0
# 8        -7.879499  10.216717     coati              29.0
# 83       -7.843497  24.805114     coati              28.0
# 75       -7.701086  30.847198     coati              22.0
# 167      -7.273461  29.079627     coati              30.0
# 88       -7.039475  14.787036     coati              25.0
# 76       -6.870878  21.876128     coati              24.0
# 192      -6.863210  27.710974     coati              26.0
# 198      -6.772749  11.135354     coati              32.0
# 48       -6.760789  30.999694     coati              32.0
# 180      -6.576941  15.767929     coati              27.0
# 94       -6.501433  13.714318     coati              21.0
# 183      -6.338280  20.824281     coati              26.0
# 188      -5.487673  13.214549     coati              28.0
# 71       -4.241667  35.796951     coati              29.0
# 23       -3.830249  21.250964     coati              33.0
# 131      -3.183573  22.439479     coati              35.0
# 138     -14.291919   4.450688      safe              37.0
# 18      -14.139895   4.633702      safe              29.0
# 83      -12.588538   5.072076      safe              27.0
#
#      weighted_interactions  num_VdW  num_hydrophobic  num_HBAcceptor  \
# 46                    47.0     17.0             12.0             2.0
# 90                    40.0     19.0              9.0             1.0
# 2                     41.0     13.0             11.0             2.0
# 125                   45.0     15.0             10.0             2.0
# 126                   45.0     12.0             10.0             3.0
# 168                   54.0     14.0             12.0             4.0
# 175                   53.0     19.0             12.0             2.0
# 111                   39.0     13.0              8.0             2.0
# 51                    49.0     14.0             11.0             3.0
# 176                   55.0     21.0             12.0             2.0
# 195                   31.0     10.0              9.0             1.0
# 30                    51.0     18.0             10.0             3.0
# 170                   45.0     15.0             10.0             2.0
# 87                    46.0     18.0              9.0             2.0
# 24                    49.0     14.0             12.0             1.0
# 56                    30.0     12.0              7.0             0.0
# 133                   41.0     14.0              7.0             3.0
# 129                   42.0     13.0             11.0             1.0
# 62                    40.0     12.0              9.0             2.0
# 97                    41.0     15.0              8.0             2.0
# 61                    40.0     15.0              9.0             1.0
# 189                   34.0     14.0             10.0             0.0
# 52                    43.0     17.0              8.0             2.0
# 145                   41.0     11.0              8.0             2.0
# 14                    37.0     12.0             11.0             1.0
# 190                   30.0      9.0              9.0             1.0
# 13                    38.0     14.0              9.0             2.0
# 10                    36.0     14.0              9.0             0.0
# 96                    37.0     17.0              8.0             0.0
# 113                   49.0     15.0             12.0             2.0
# 169                   46.0     15.0              9.0             3.0
# 21                    48.0     13.0             11.0             3.0
# 154                   26.0     12.0              7.0             0.0
# 8                     46.0     16.0             10.0             2.0
# 83                    40.0     15.0             11.0             1.0
# 75                    32.0     13.0              6.0             1.0
# 167                   45.0     17.0              9.0             2.0
# 88                    34.0     15.0              8.0             1.0
# 76                    35.0     14.0              9.0             1.0
# 192                   36.0     17.0              8.0             1.0
# 198                   51.0     18.0             10.0             3.0
# 48                    45.0     19.0             10.0             2.0
# 180                   38.0     17.0              9.0             1.0
# 94                    33.0     11.0              9.0             0.0
# 183                   37.0     15.0             11.0             0.0
# 188                   40.0     17.0              8.0             1.0
# 71                    41.0     19.0              8.0             2.0
# 23                    45.0     19.0             13.0             0.0
# 131                   56.0     19.0             12.0             3.0
# 138                   56.0     21.0             11.0             3.0
# 18                    48.0     13.0             11.0             3.0
# 83                    45.0     13.0             11.0             2.0
#
#      num_ionic  IFP Intersection  Weighted IFP Intersection  \
# 46         0.0                19                         33
# 90         0.0                17                         27
# 2          0.0                21                         39
# 125        1.0                23                         43
# 126        1.0                23                         45
# 168        1.0                25                         49
# 175        1.0                21                         41
# 111        1.0                21                         39
# 51         1.0                24                         46
# 176        1.0                26                         47
# 195        0.0                16                         30
# 30         1.0                22                         43
# 170        1.0                22                         42
# 87         1.0                20                         39
# 24         2.0                19                         37
# 56         1.0                14                         27
# 133        1.0                20                         39
# 129        1.0                20                         38
# 62         1.0                19                         37
# 97         1.0                20                         38
# 61         1.0                20                         37
# 189        0.0                18                         30
# 52         1.0                22                         40
# 145        2.0                19                         37
# 14         0.0                17                         32
# 190        0.0                12                         23
# 13         0.0                20                         36
# 10         1.0                17                         32
# 96         1.0                18                         32
# 113        1.0                24                         45
# 169        1.0                23                         44
# 21         1.0                24                         47
# 154        0.0                13                         23
# 8          1.0                24                         44
# 83         0.0                19                         34
# 75         1.0                16                         30
# 167        1.0                20                         39
# 88         0.0                17                         30
# 76         0.0                18                         32
# 192        0.0                17                         28
# 198        1.0                23                         44
# 48         0.0                22                         39
# 180        0.0                15                         26
# 94         1.0                18                         33
# 183        0.0                17                         29
# 188        1.0                18                         34
# 71         0.0                16                         29
# 23         0.0                18                         30
# 131        1.0                26                         49
# 138        1.0                26                         49
# 18         1.0                23                         44
# 83         1.0                23                         44
#
#                                           ring_systems  \
# 46   [(O=c1cc2ccccc2c[nH]1, 86), (c1ccccc1, 2260082...
# 90   [(O=c1cc2ccccc2c[nH]1, 86), (c1ccccc1, 2260082...
# 2    [(C1N=NN=N1, 59), (O=c1[nH]ccc2ccccc12, 2230),...
# 125  [(C1=Cc2ccccc2[NH+]=CN1, 0), (c1ccccc1, 226008...
# 126  [(O=C1C=CN1, 0), (c1ccccc1, 2260082), (c1ccccc...
# 168  [(O=c1[nH]ccc2ccsc12, 7), (c1ccccc1, 2260082),...
# 175  [(C1=CNc2ccccc2N1, 2), (c1ccccc1, 2260082), (c...
# 111  [(c1coc2ccc-2[nH]1, 0), (c1ccccc1, 2260082), (...
# 51   [(O=c1[nH]c(=O)c2ccccc2c[nH+]1, 0), (c1ccccc1,...
# 176  [(O=c1[nH]c[nH+]c2[nH]ncc12, 0), (c1ccccc1, 22...
# 195  [(C1=CC=C1, 9), (c1ccc2[nH]ccc2c1, 93446), (c1...
# 30   [(C=C1NC(=O)c2ccccc21, 64), (c1ccccc1, 2260082...
# 170  [(C1=Cc2ccccc2[NH+]=CN1, 0), (c1ccccc1, 226008...
# 87   [(O=c1cc[nH]c2c1=CN=2, 0), (c1ccccc1, 2260082)...
# 24   [(c1c[nH+]c2cc[nH]c2c1, 31), (c1ccccc1, 226008...
# 56   [(O=C1C=NCNc2ccccc21, 0), (c1ccccc1, 2260082),...
# 133  [(c1cc2n(c1)CNCC2, 0), (c1ccccc1, 2260082), (c...
# 129  [(c1c[nH+]c2[nH]ccc2c1, 5), (c1ccccc1, 2260082...
# 62   [(O=C1CNC(=O)c2ccccc21, 0), (c1ccccc1, 2260082...
# 97   [(O=C1C=Cn2cccc21, 0), (c1ccccc1, 2260082), (c...
# 61   [(C=C1Nc2ccccc21, 7), (c1ccccc1, 2260082), (c1...
# 189  [(c1ccc2[n-]ccc2c1, 0), (C1=C[NH2+]CC1, 0), (c...
# 52   [(O=c1c[nH+]ccc2ccccc12, 0), (c1ccccc1, 226008...
# 145  [(O=c1[nH]c[nH+]c2ccccc12, 2), (c1ccccc1, 2260...
# 14      [(C=C1SCc2ccccc2C1=O, 0), (c1ccccc1, 2260082)]
# 190   [(C=C1NC(=O)c2ccccc21, 64), (c1ccccc1, 2260082)]
# 13   [(C1=CC2C=Cc3ccccc3C2=C1, 0), (C1CC1, 70914), ...
# 10   [(C=C1NC(=O)c2ccccc21, 64), (c1ccccc1, 2260082...
# 96   [(O=C1NC=CC=Cc2ccccc21, 1), (c1ccccc1, 2260082...
# 113  [(C=C1CNc2ccccc2C1=O, 36), (c1ccccc1, 2260082)...
# 169  [(O=c1ccccc2ccccc12, 83), (c1ccccc1, 2260082),...
# 21   [(O=C1CNc2ccccc21, 38), (c1ccccc1, 2260082), (...
# 154  [(O=C1Cc2ccccc2[NH2+]N1, 0), (c1ccccc1, 226008...
# 8    [(O=C1C=CNc2ccccc2O1, 0), (c1ccccc1, 2260082),...
# 83   [(O=c1ccccc2ccccc12, 83), (c1ccccc1, 2260082),...
# 75   [(O=c1ccc(=O)c2ccccc2[nH]1, 10), (c1ccccc1, 22...
# 167  [(O=C1CCc2cc3ccccc3c(=O)n2CCO1, 0), (c1ccccc1,...
# 88   [(C=C1NC(=O)Cc2ccccc21, 0), (c1ccccc1, 2260082...
# 76   [(O=C1C=Cc2ccccc2CO1, 1), (c1ccccc1, 2260082),...
# 192  [(C=C1CCn2ccnc21, 0), (c1ccccc1, 2260082), (c1...
# 198  [(O=c1[nH]c2ncccccc1-2, 0), (c1ccccc1, 2260082...
# 48   [(O=c1[nH]c[nH+]c2ccccc12, 2), (c1ccccc1, 2260...
# 180  [(O=c1ccccn2ncnc12, 0), (c1ccccc1, 2260082), (...
# 94   [(O=C1CNc2ccccc21, 38), (c1ccccc1, 2260082), (...
# 183  [(C1=CNc2ccccc2C=N1, 0), (c1ccccc1, 2260082), ...
# 188  [(C=C1C=CC(=O)c2ccccc2N1, 0), (c1ccccc1, 22600...
# 71   [(O=c1cccc[nH]c2ccc1-2, 0), (c1ccccc1, 2260082...
# 23   [(C1=CNc2ccccc2C=C1, 0), (c1ccccc1, 2260082), ...
# 131  [(O=C1c2ccccc2NNc2ccccc21, 0), (c1ccccc1, 2260...
# 138  [(C1=CNCC=N1, 3), (O=c1[nH]ccc2ccccc12, 2230),...
# 18   [(O=S1(=O)N=CC=N1, 13), (O=c1[nH]ccc2ccccc12, ...
# 83   [(C1C[C@@H]2C[C@H](N1)N2, 0), (O=c1[nH]ccc2ccc...
#
#                          min_ring min_freq
# 46            O=c1cc2ccccc2c[nH]1       86
# 90            O=c1cc2ccccc2c[nH]1       86
# 2                       C1N=NN=N1       59
# 125         C1=Cc2ccccc2[NH+]=CN1        0
# 126                     O=C1C=CN1        0
# 168            O=c1[nH]ccc2ccsc12        7
# 175               C1=CNc2ccccc2N1        2
# 111              c1coc2ccc-2[nH]1        0
# 51   O=c1[nH]c(=O)c2ccccc2c[nH+]1        0
# 176     O=c1[nH]c[nH+]c2[nH]ncc12        0
# 195                      C1=CC=C1        9
# 30            C=C1NC(=O)c2ccccc21       64
# 170         C1=Cc2ccccc2[NH+]=CN1        0
# 87            O=c1cc[nH]c2c1=CN=2        0
# 24           c1c[nH+]c2cc[nH]c2c1       31
# 56             O=C1C=NCNc2ccccc21        0
# 133               c1cc2n(c1)CNCC2        0
# 129          c1c[nH+]c2[nH]ccc2c1        5
# 62           O=C1CNC(=O)c2ccccc21        0
# 97                O=C1C=Cn2cccc21        0
# 61                 C=C1Nc2ccccc21        7
# 189              c1ccc2[n-]ccc2c1        0
# 52          O=c1c[nH+]ccc2ccccc12        0
# 145       O=c1[nH]c[nH+]c2ccccc12        2
# 14             C=C1SCc2ccccc2C1=O        0
# 190           C=C1NC(=O)c2ccccc21       64
# 13         C1=CC2C=Cc3ccccc3C2=C1        0
# 10            C=C1NC(=O)c2ccccc21       64
# 96           O=C1NC=CC=Cc2ccccc21        1
# 113            C=C1CNc2ccccc2C1=O       36
# 169             O=c1ccccc2ccccc12       83
# 21                O=C1CNc2ccccc21       38
# 154         O=C1Cc2ccccc2[NH2+]N1        0
# 8              O=C1C=CNc2ccccc2O1        0
# 83              O=c1ccccc2ccccc12       83
# 75       O=c1ccc(=O)c2ccccc2[nH]1       10
# 167  O=C1CCc2cc3ccccc3c(=O)n2CCO1        0
# 88           C=C1NC(=O)Cc2ccccc21        0
# 76             O=C1C=Cc2ccccc2CO1        1
# 192                C=C1CCn2ccnc21        0
# 198          O=c1[nH]c2ncccccc1-2        0
# 48        O=c1[nH]c[nH+]c2ccccc12        2
# 180              O=c1ccccn2ncnc12        0
# 94                O=C1CNc2ccccc21       38
# 183             C1=CNc2ccccc2C=N1        0
# 188        C=C1C=CC(=O)c2ccccc2N1        0
# 71           O=c1cccc[nH]c2ccc1-2        0
# 23              C1=CNc2ccccc2C=C1        0
# 131       O=C1c2ccccc2NNc2ccccc21        0
# 138                    C1=CNCC=N1        3
# 18                O=S1(=O)N=CC=N1       13
# 83         C1C[C@@H]2C[C@H](N1)N2        0

# %%
bad_smiles = bad_rings['SMILES']

bad_mols = [Chem.MolFromSmiles(smile) for smile in bad_smiles]

# %%
mols2grid.display(bad_mols, size=(250, 125))
# Out:
# MolGridWidget()
# <style>
#     /* Some CSS to integrate with Jupyter more cleanly */
#     div.output_subarea {
#         /* Undo an unfortunate max-width parameter
#         that causes the output area to be too narrow
#         on smaller screens. */
#         max-width: none;
#
#         /* Align the table with the content */
#         padding: 0;
#
#         /* Let it breathe */
#         margin-top: 20px;
#     }
# </style>
#
# <iframe class="mols2grid-iframe" frameborder="0" width="100%"
#
#
#     allow="clipboard-write"
#
#
#     sandbox="allow-scripts allow-same-origin allow-downloads allow-popups allow-modals"
#
#     srcdoc="
#
#
#
# &lt;html lang=&quot;en&quot;&gt;
#     &lt;head&gt;
#         &lt;meta charset=&quot;UTF-8&quot; /&gt;
#         &lt;meta http-equiv=&quot;X-UA-Compatible&quot; content=&quot;IE=edge&quot; /&gt;
#         &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot; /&gt;
#         &lt;title&gt;Document!&lt;/title&gt;
#
#
#
#         &lt;style&gt;
#             /**
#  * General styling
#  */
# body {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
# }
# h1,h2,h3,h4 {
#     margin: 0 0 10px 0;
# }
# h1 {
#     font-size: 26px;
# }
# h2 {
#     font-size: 20px;
#     font-weight: 400;
# }
# h3 {
# 	font-size: 16px;
# }
# p {
#     margin: 0 0 10px 0;
# }
#
#
# /* Remove body margin inside iframe */
# body.m2g-inside-iframe {
#     margin: 0;
# }
#
# /* In-cell text */
# #mols2grid .data:not(.data-img) {
#     height: 16px;
#     line-height: 16px;
# }
# /* Text truncation */
# #mols2grid .data {
#     /* Break text into multiple lines (default for static)... */
#     word-wrap: normal;
#
#     /* ...or truncate it (default for interactive). */
#     overflow: hidden;
#     white-space: nowrap;
#     text-overflow: ellipsis;
# }
#
#
# /**
#  * Popover
#  * - - -
#  * Note: this is a bootstrap variable which is not namespaced.
#  * To avoid any contamination, we only style it when the
#  * x-placement parameter is set.
#  */
# .popover[x-placement] {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     background: white;
#     border: solid 1px rgba(0,0,0,.2);
#     font-size: 12px;
#     padding: 10px;
#     border-radius: 5px;
#     box-shadow: 0 0 20px rgba(0,0,0,.15);
#     user-select: none;
# }
# .popover[x-placement] h3 {
#     margin: 0;
# }
# .popover[x-placement] .arrow {
#     width: 10px;
#     height: 10px;
#     background: #fff;
#     border: solid 1px rgba(0,0,0,.2);
#     box-sizing: border-box;
#     position: absolute;
#     transform-origin: 5px 5px;
#     clip-path: polygon(0 0, 100% 0, 100% 100%);
# }
# .popover[x-placement=&#x27;left&#x27;] .arrow {
#     transform: rotate(45deg);
#     top: 50%;
#     right: -5px;
# }
# .popover[x-placement=&#x27;right&#x27;] .arrow {
#     transform: rotate(-135deg);
#     top: 50%;
#     left: -5px;
# }
# .popover[x-placement=&#x27;top&#x27;] .arrow {
#     transform: rotate(135deg);
#     left: 50%;
#     bottom: -5px;
# }
# .popover[x-placement=&#x27;bottom&#x27;] .arrow {
#     transform: rotate(-45deg);
#     left: 50%;
#     top: -5px;
# }
#             body {
#     /* Colors */
#     --m2g-black: rgba(0,0,0,.75);
#     --m2g-black-soft: rgba(0,0,0,.35);
#     --m2g-black-10: rgba(0,0,0,.1);
#     --m2g-bg: #f6f6f6;
#     --m2g-border: solid 1px rgba(0,0,0,0.2);
#     --m2g-hl: #555; /* Highlight color */
#     --m2g-hl-shadow: inset 0 0 0 1px var(--m2g-hl); /* Inset 1px shadow to make border thicker */
#     --m2g-blue: #0f62fe;
#     --m2g-blue-soft: rgba(15,98,254,.2);
#
#     /* Icons */
#     --m2g-icn-triangle: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;20&quot; fill=&quot;rgba(0,0,0,.75)&quot; height=&quot;20&quot; viewBox=&quot;0 0 20 20&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M9.5713 13.285L6.2543 7.757C6.0543 7.424 6.2953 7 6.6823 7L13.3173 7C13.7053 7 13.9463 7.424 13.7453 7.757L10.4283 13.285C10.2343 13.609 9.7653 13.609 9.5713 13.285Z&quot;/&gt;&lt;/svg&gt;&#x27;);
#     --m2g-icn-triangle-white: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;20&quot; fill=&quot;white&quot; height=&quot;20&quot; viewBox=&quot;0 0 20 20&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M9.5713 13.285L6.2543 7.757C6.0543 7.424 6.2953 7 6.6823 7L13.3173 7C13.7053 7 13.9463 7.424 13.7453 7.757L10.4283 13.285C10.2343 13.609 9.7653 13.609 9.5713 13.285Z&quot;/&gt;&lt;/svg&gt;&#x27;);
#     --m2g-icn-cb-white: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;16&quot; height=&quot;16&quot; viewBox=&quot;0 0 16 16&quot; fill=&quot;none&quot; stroke=&quot;white&quot; stroke-width=&quot;2.5&quot; stroke-linecap=&quot;round&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M4 7.65686L7 10.6569L12.6569 5.00001&quot;/&gt;&lt;/svg&gt;&#x27;);
#
#     /* Border radius */
#     --m2g-br: 3px;
#     --m2g-br-l: var(--m2g-br) 0 0 var(--m2g-br); /* Left-only */
#     --m2g-br-r: 0 var(--m2g-br) var(--m2g-br) 0; /* Right-only */
#
#     /* Text */
#     --m2g-fs: 14px; /* UI font-size */
#     --m2g-fs-cell: 12px; /* Cell font-size */
#
#     /* Transition speeds */
#     --m2g-trans: 150ms;
#
#     /* Layout */
#     --m2g-h: 40px; /* Form element height */
# }
#
# /* Styling */
# #mols2grid {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     font-size: var(--m2g-fs);
# }
#
# /* Fixes */
# #mols2grid *,
# #mols2grid *::before,
# #mols2grid *::after {
#     box-sizing: border-box;
#     outline: none;
# }
#
#
#
# /**
#  * Functions section
#  */
#
# #mols2grid .m2g-functions {
#     display: flex;
# }
# #mols2grid .m2g-functions .m2g-row {
#     flex: 0;
#     display: flex;
# }
#
# /* Individual elements don&#x27;t scale */
# #mols2grid .m2g-functions .m2g-row &gt; * {
#     flex: 0 0;
#     margin-right: 10px;
# }
# #mols2grid .m2g-functions .m2g-row:last-child &gt; *:last-child {
#     margin-right: 0;
# }
#
# /* Row 1: pagination + gap + sort */
# #mols2grid .m2g-functions .m2g-row:first-child {
#     flex: 1; /* Scale */
# }
# #mols2grid .m2g-functions .m2g-gap {
#     /* The gap in between will scale, so the pagination
#     stays on the left, while the rest moves to the right */
#     flex: 1;
#     margin-right: 0;
# }
#
#
#
# /*
#  * Pagination
#  */
#
# #mols2grid ul.m2g-pagination {
#     /* Unset defaults */
#     list-style-type: none;
#     margin-block-start: 0;
#     margin-block-end: 0;
#     margin-inline-start: 0;
#     margin-inline-end: 0;
#     padding-inline-start: 0;
#
#     /* Custom */
#     display: flex;
# }
# #mols2grid ul.m2g-pagination li {
#     background: var(--m2g-bg) ;
#     border: var(--m2g-border);
#     height: var(--m2g-h);
#     min-width: calc(var(--m2g-h) + 1px);
#     position: relative;
#     user-select: none;
#
#     /* Compensate for double border */
#     margin-right: -1px;
#
#     /* Center text */
#     display: flex;
#     align-items: center;
#     justify-content: center;
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     min-width: var(--m2g-h);
# }
# #mols2grid ul.m2g-pagination li a {
#     text-decoration: none;
#     color: var(--m2g-black);
#     padding: 0 10px;
#     width: 100%;
#     height: var(--m2g-h);
#     line-height: var(--m2g-h);
#     text-align: center;
#     /* Compensate for border so there&#x27;s no gap between click areas  */
#     margin: 0 -1px;
# }
#
# /* Corner shape */
# #mols2grid ul.m2g-pagination li:first-child {
#     border-radius: var(--m2g-br-l);
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     border-radius: var(--m2g-br-r);
#     margin-right: 0;
# }
#
# /* Focus state */
# #mols2grid ul.m2g-pagination li:focus-within {
#     border-color: var(--m2g-hl);
#     box-shadow: var(--m2g-hl-shadow);
#     z-index: 1;
# }
#
# /* Active state */
# #mols2grid ul.m2g-pagination li.active {
#     background: var(--m2g-hl);
#     z-index: 1;
# }
# #mols2grid ul.m2g-pagination li.active a {
#     cursor: default;
#     color: #fff;
# }
#
# /* Disabled sate */
# #mols2grid ul.m2g-pagination li.disabled a {
#     cursor: default;
#     color: rgba(0,0,0,.25);
#     pointer-events: none;
# }
#
#
#
# /*
#  * Dropdowns
#  */
#
# #mols2grid ::placeholder {
#     color: var(--m2g-black-soft);
# }
# #mols2grid .m2g-dropdown {
#     height: var(--m2g-h);
#     background: var(--m2g-bg);
#     border: var(--m2g-border);
#     border-radius: var(--m2g-br);
#     position: relative;
# }
# #mols2grid .m2g-dropdown select {
#     -webkit-appearance: none;
#     -moz-appearance: none;
#     -ms-appearance: none;

# %%
category_counts = bad_rings['Model'].value_counts()

# Step 4: Plot the bar chart
category_counts.plot(kind='bar', color='skyblue', edgecolor='black')
# Out:
# <Axes: xlabel='Model'>

# %%
sns.displot(model_df.rmsd);

# %%
df_rmsd_ok = model_df.query("rmsd <= 10").copy()

# %%
df_rmsd_ok
# Out:
#                                                 SMILES       ID  \
# 121  CCOC(=O)c1c(-c2ccccc2)c2cc(C(F)(F)F)ccc2c(=O)n...  MOL0121
# 196  COCC(=O)/C=C/c1c(-c2ccccc2)c2cc(Cl)ccc2c(=O)n1...  MOL0196
# 150  CCC(=O)c1ccc(Cn2c(C(=O)OC)c(-c3ccccc3)c3cc(Cl)...  MOL0150
# 99   COc1ccc2c(=O)n(Cc3ccc(C(=O)O)cc3)c(/C=C/C(=O)O...  MOL0099
# 127  CC(=O)c1c(-c2ccccc2)c2cc(C(F)(F)F)ccc2c(=O)n1C...  MOL0127
# ..                                                 ...      ...
# 12   O=C([O-])c1ccc(Cn2c(C(=O)CCC3CCNCC3)c(-c3ccccc...  MOL0012
# 191  O=C([O-])c1ccc(C(N2CCOCC2)n2c(C(=O)CCN3CCOCC3)...  MOL0191
# 115  O=C([O-])c1ccc(C(SC(F)(F)F)n2c(C(=O)CCNC(O)=NC...  MOL0115
# 24   O=C([O-])c1ccc(C(N2CCOCC2)n2c(C(=O)CCn3cc[n+](...  MOL0024
# 144  O=C([O-])c1ccc(C(c2ccccc2)n2c(C(=O)CCc3ccco3)c...  MOL0144
#
#      Docking score      rmsd     Model  num_interactions  \
# 121     -16.624857  3.737471  reinvent              27.0
# 196     -16.540930  3.676144  reinvent              32.0
# 150     -16.529593  5.569642  reinvent              25.0
# 99      -16.301600  3.785833  reinvent              29.0
# 127     -16.295380  5.360354  reinvent              27.0
# ..             ...       ...       ...               ...
# 12       -9.905931  6.989526      safe              28.0
# 191      -8.210854  6.725291      safe              33.0
# 115      -8.133378  6.221507      safe              33.0
# 24       -7.557238  3.956228      safe              33.0
# 144      -6.479462  5.696628      safe              33.0
#
#      weighted_interactions  num_VdW  num_hydrophobic  num_HBAcceptor  \
# 121                   45.0     13.0             10.0             4.0
# 196                   48.0     17.0             11.0             3.0
# 150                   40.0     11.0             10.0             3.0
# 99                    45.0     16.0             10.0             3.0
# 127                   42.0     14.0             11.0             2.0
# ..                     ...      ...              ...             ...
# 12                    49.0     13.0             11.0             2.0
# 191                   51.0     18.0             10.0             3.0
# 115                   52.0     18.0              9.0             4.0
# 24                    55.0     17.0             11.0             4.0
# 144                   52.0     16.0             13.0             2.0
#
#      num_ionic  IFP Intersection  Weighted IFP Intersection  \
# 121        0.0                21                         39
# 196        0.0                24                         41
# 150        0.0                20                         36
# 99         0.0                22                         38
# 127        0.0                20                         35
# ..         ...               ...                        ...
# 12         2.0                23                         44
# 191        1.0                24                         44
# 115        1.0                22                         40
# 24         1.0                25                         48
# 144        1.0                23                         43
#
#                                           ring_systems             min_ring  \
# 121  [(O=c1[nH]ccc2ccccc12, 2230), (c1ccccc1, 22600...  O=c1[nH]ccc2ccccc12
# 196  [(O=c1[nH]ccc2ccccc12, 2230), (c1ccccc1, 22600...  O=c1[nH]ccc2ccccc12
# 150  [(O=c1[nH]ccc2ccccc12, 2230), (c1ccccc1, 22600...  O=c1[nH]ccc2ccccc12
# 99   [(O=c1[nH]ccc2ccccc12, 2230), (c1ccccc1, 22600...  O=c1[nH]ccc2ccccc12
# 127  [(O=c1[nH]ccc2ccccc12, 2230), (c1ccccc1, 22600...  O=c1[nH]ccc2ccccc12
# ..                                                 ...                  ...
# 12   [(O=c1[nH]ccc2ccccc12, 2230), (c1cc[nH+]cc1, 1...  O=c1[nH]ccc2ccccc12
# 191  [(O=c1[nH]ccc2ccccc12, 2230), (C1COCCN1, 70960...  O=c1[nH]ccc2ccccc12
# 115  [(O=c1[nH]ccc2ccccc12, 2230), (c1ccccc1, 22600...  O=c1[nH]ccc2ccccc12
# 24   [(c1c[nH+]c[nH]1, 2209), (O=c1[nH]ccc2ccccc12,...       c1c[nH+]c[nH]1
# 144  [(O=c1[nH]ccc2ccccc12, 2230), (c1ccoc1, 62191)...  O=c1[nH]ccc2ccccc12
#
#     min_freq
# 121     2230
# 196     2230
# 150     2230
# 99      2230
# 127     2230
# ..       ...
# 12      2230
# 191     2230
# 115     2230
# 24      2209
# 144     2230
#
# [643 rows x 16 columns]

# %%
sns.displot(df_rmsd_ok.Model);

# %%
smiles = df_rmsd_ok['SMILES'].to_list()

# %%
y = df_rmsd_ok['Model'].to_numpy().reshape(-1, 1)

# %% [markdown]
# ### Evaluating Metrics w/ MolScore

# %%
from molscore import MolScore

# %%
ms = MolScore(model_name='mol2mol', task_config='molscore/feature_selection.json')
scores = ms.score(smiles)
# Out:
# Found existing directory, appending current time to distinguish
# Found existing rascore-env
# Launching server: conda run -n rascore-env python /home/fts_g_ucla_edu/.local/lib/python3.10/site-packages/molscore/scoring_functions/servers/rascore_server.py --port 8029 --model_path /home/fts_g_ucla_edu/.local/lib/python3.10/site-packages/molscore/data/models/RAScore/XGB_chembl_ecfp_counts/model.pkl

# %%
# Once finished
metrics = ms.compute_metrics(
    endpoints=None, # Optional list: by default will use the running final score/reward value
    thresholds=None,  # Optional list: if specified will calculate the yield of molecules above that threshold 
    # chemistry_filters_basic=False,  # Optional, bool: Additionally re-calculate metrics after filtering out unreasonable chemistry
    budget=10000,  # Optional, int: Calculate metrics only with molecules within this budget
    n_jobs=1,  # Optional, int: Multiprocessing
    benchmark=None,  # Optional, str: Name of benchmark, this may specify additional metrics to compute
)

# %%
df = pd.read_csv('molscore/2024_07_30_mol2mol_feature_selection_16_14_19/iterations/000001_scores.csv', index_col=0)

# %%
df.head()
# Out:
#      model               task  step  batch_idx  absolute_time  \
# 0  mol2mol  feature_selection     1          0       2.946556
# 1  mol2mol  feature_selection     1          1       2.946556
# 2  mol2mol  feature_selection     1          2       2.946556
# 3  mol2mol  feature_selection     1          3       2.946556
# 4  mol2mol  feature_selection     1          4       2.946556
#
#                                               smiles  valid  valid_score  \
# 0  CCOC(=O)c1c(-c2ccccc2)c2cc(C(F)(F)F)ccc2c(=O)n...   True            1
# 1  COCC(=O)/C=C/c1c(-c2ccccc2)c2cc(Cl)ccc2c(=O)n1...   True            1
# 2  CCC(=O)c1ccc(Cn2c(C(=O)OC)c(-c3ccccc3)c3cc(Cl)...   True            1
# 3  COc1ccc2c(=O)n(Cc3ccc(C(=O)O)cc3)c(/C=C/C(=O)O...   True            1
# 4  CC(=O)c1c(-c2ccccc2)c2cc(C(F)(F)F)ccc2c(=O)n1C...   True            1
#
#    unique  occurrences  ...  desc_FlourineCount  tanimoto_Sim  \
# 0    True            0  ...                   3      0.514286
# 1    True            0  ...                   0      0.521127
# 2    True            0  ...                   0      0.733333
# 3    True            0  ...                   0      0.438356
# 4    True            0  ...                   3      0.522388
#
#    tanimoto_Cmpd1_Sim  dice_Sim  dice_Cmpd1_Sim  RAScore_pred_proba  \
# 0            0.514286  0.679245        0.679245            0.982867
# 1            0.521127  0.685185        0.685185            0.948534
# 2            0.733333  0.846154        0.846154            0.910709
# 3            0.438356  0.609524        0.609524            0.945486
# 4            0.522388  0.686275        0.686275            0.957991
#
#    raw_valid_score  amean  filter  score_time
# 0                1    1.0     1.0    6.142683
# 1                1    1.0     1.0    6.142683
# 2                1    1.0     1.0    6.142683
# 3                1    1.0     1.0    6.142683
# 4                1    1.0     1.0    6.142683
#
# [5 rows x 39 columns]

# %%
df.drop(['desc_MolecularFormula',
         'dice_Sim', 'dice_Cmpd1_Sim',
         'tanimoto_Sim', 'tanimoto_Cmpd1_Sim',
         'desc_SAscore', 'desc_PenLogP',
         'desc_MolWt', 'desc_NumHAcceptors',
         'desc_NumHDonors', 'desc_CLogP',
         'desc_TPSA', 'desc_NumRotatableBonds',
         'desc_MaxConsecutiveRotatableBonds',
         'desc_NumAromaticRings', 'desc_FlourineCount',
         'desc_FormalCharge', 'desc_RingCount',
         'desc_NumAliphaticRings', 'desc_HeavyAtomCount',
         'desc_HeavyAtomMolWt'], axis=1, inplace=True)

# %%
X = df.iloc[:, 10:-4]

# %% [markdown]
# Adding new features

# %%
weighted_ifp_intersection = df_rmsd_ok['Weighted IFP Intersection'].values

X['Docking score'] = df_rmsd_ok['Docking score'].values
X['interaction weight ratio'] = df_rmsd_ok['weighted_interactions'].values / df_rmsd_ok['num_interactions'].values
X['rmsd'] = df_rmsd_ok['rmsd'].values
X['Weighted IFP Similarity'] = weighted_ifp_intersection / df_rmsd_ok['weighted_interactions'].values

# %%
X.head()
# Out:
#    desc_QED  desc_NumHeteroatoms   desc_Bertz  RAScore_pred_proba  \
# 0  0.351621                    9  1507.458087            0.982867
# 1  0.340885                    7  1488.314380            0.948534
# 2  0.271819                    6  1406.508497            0.910709
# 3  0.397044                    7  1467.520115            0.945486
# 4  0.387424                    8  1470.935757            0.957991
#
#    Docking score  interaction weight ratio      rmsd  Weighted IFP Similarity
# 0     -16.624857                  1.666667  3.737471                 0.866667
# 1     -16.540930                  1.500000  3.676144                 0.854167
# 2     -16.529593                  1.600000  5.569642                 0.900000
# 3     -16.301600                  1.551724  3.785833                 0.844444
# 4     -16.295380                  1.555556  5.360354                 0.833333

# %% [markdown]
# #### Exploratory Data Analysis:
#
# * Normalizing columns
# * Evaluating correlations between features

# %%
X[:3].plot(kind='bar', legend=False, logy=True);

# %%
X_normalized = X.drop(['Docking score'], axis=1)

X_normalized['Docking score'] = np.abs(X['Docking score'])

# Normalizing each column using min-max scaler
for column in X_normalized.columns:
   
   X_normalized[column] = (X_normalized[column] - X_normalized[column].min()) / (X_normalized[column].max() - X_normalized[column].min())

# X_normalized['desc_CLogP'] = X['desc_CLogP'] / X['desc_CLogP'].max()

# %%
X_normalized[:3].plot(kind='bar', legend=False, logy=True);

# %%
enc = OrdinalEncoder()

ord = enc.fit_transform(y)

# %%
X['Model'] = ord.squeeze()

# %%
X.corr().style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style type="text/css">
# #T_53852_row0_col0, #T_53852_row1_col1, #T_53852_row2_col2, #T_53852_row3_col3, #T_53852_row4_col4, #T_53852_row5_col5, #T_53852_row6_col6, #T_53852_row7_col7, #T_53852_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_53852_row0_col1, #T_53852_row1_col0 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_53852_row0_col2, #T_53852_row2_col0 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_53852_row0_col3, #T_53852_row3_col0 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_53852_row0_col4, #T_53852_row0_col7, #T_53852_row4_col0, #T_53852_row7_col0 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_53852_row0_col5, #T_53852_row5_col0 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_53852_row0_col6, #T_53852_row6_col0 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_53852_row0_col8, #T_53852_row2_col6, #T_53852_row6_col2, #T_53852_row8_col0 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_53852_row1_col2, #T_53852_row2_col1 {
#   background-color: #de614d;
#   color: #f1f1f1;
# }
# #T_53852_row1_col3, #T_53852_row3_col1 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_53852_row1_col4, #T_53852_row4_col1 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_53852_row1_col5, #T_53852_row5_col1, #T_53852_row5_col8, #T_53852_row8_col5 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_53852_row1_col6, #T_53852_row6_col1 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_53852_row1_col7, #T_53852_row7_col1 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_53852_row1_col8, #T_53852_row8_col1 {
#   background-color: #ec8165;
#   color: #f1f1f1;
# }
# #T_53852_row2_col3, #T_53852_row3_col2 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_53852_row2_col4, #T_53852_row4_col2 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_53852_row2_col5, #T_53852_row5_col2 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_53852_row2_col7, #T_53852_row7_col2 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_53852_row2_col8, #T_53852_row8_col2 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_53852_row3_col4, #T_53852_row4_col3 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_53852_row3_col5, #T_53852_row5_col3 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_53852_row3_col6, #T_53852_row6_col3 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_53852_row3_col7, #T_53852_row7_col3 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_53852_row3_col8, #T_53852_row8_col3 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_53852_row4_col5, #T_53852_row5_col4 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_53852_row4_col6, #T_53852_row6_col4 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_53852_row4_col7, #T_53852_row7_col4 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_53852_row4_col8, #T_53852_row8_col4 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_53852_row5_col6, #T_53852_row6_col5 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_53852_row5_col7, #T_53852_row7_col5 {
#   background-color: #f5a081;
#   color: #000000;
# }
# #T_53852_row6_col7, #T_53852_row7_col6 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_53852_row6_col8, #T_53852_row8_col6 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_53852_row7_col8, #T_53852_row8_col7 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# </style>
# <table id="T_53852">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_53852_level0_col0" class="col_heading level0 col0" >desc_QED</th>
#       <th id="T_53852_level0_col1" class="col_heading level0 col1" >desc_NumHeteroatoms</th>
#       <th id="T_53852_level0_col2" class="col_heading level0 col2" >desc_Bertz</th>
#       <th id="T_53852_level0_col3" class="col_heading level0 col3" >RAScore_pred_proba</th>
#       <th id="T_53852_level0_col4" class="col_heading level0 col4" >Docking score</th>
#       <th id="T_53852_level0_col5" class="col_heading level0 col5" >interaction weight ratio</th>
#       <th id="T_53852_level0_col6" class="col_heading level0 col6" >rmsd</th>
#       <th id="T_53852_level0_col7" class="col_heading level0 col7" >Weighted IFP Similarity</th>
#       <th id="T_53852_level0_col8" class="col_heading level0 col8" >Model</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_53852_level0_row0" class="row_heading level0 row0" >desc_QED</th>
#       <td id="T_53852_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_53852_row0_col1" class="data row0 col1" >-0.275191</td>
#       <td id="T_53852_row0_col2" class="data row0 col2" >-0.552671</td>
#       <td id="T_53852_row0_col3" class="data row0 col3" >0.085952</td>
#       <td id="T_53852_row0_col4" class="data row0 col4" >-0.200337</td>
#       <td id="T_53852_row0_col5" class="data row0 col5" >-0.006372</td>
#       <td id="T_53852_row0_col6" class="data row0 col6" >-0.031462</td>
#       <td id="T_53852_row0_col7" class="data row0 col7" >-0.199562</td>
#       <td id="T_53852_row0_col8" class="data row0 col8" >-0.270550</td>
#     </tr>
#     <tr>
#       <th id="T_53852_level0_row1" class="row_heading level0 row1" >desc_NumHeteroatoms</th>
#       <td id="T_53852_row1_col0" class="data row1 col0" >-0.275191</td>
#       <td id="T_53852_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_53852_row1_col2" class="data row1 col2" >0.742906</td>
#       <td id="T_53852_row1_col3" class="data row1 col3" >-0.178248</td>
#       <td id="T_53852_row1_col4" class="data row1 col4" >0.184621</td>
#       <td id="T_53852_row1_col5" class="data row1 col5" >0.264955</td>
#       <td id="T_53852_row1_col6" class="data row1 col6" >-0.348065</td>
#       <td id="T_53852_row1_col7" class="data row1 col7" >-0.053745</td>
#       <td id="T_53852_row1_col8" class="data row1 col8" >0.612684</td>
#     </tr>
#     <tr>
#       <th id="T_53852_level0_row2" class="row_heading level0 row2" >desc_Bertz</th>
#       <td id="T_53852_row2_col0" class="data row2 col0" >-0.552671</td>
#       <td id="T_53852_row2_col1" class="data row2 col1" >0.742906</td>
#       <td id="T_53852_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_53852_row2_col3" class="data row2 col3" >-0.043068</td>
#       <td id="T_53852_row2_col4" class="data row2 col4" >0.286762</td>
#       <td id="T_53852_row2_col5" class="data row2 col5" >0.296674</td>
#       <td id="T_53852_row2_col6" class="data row2 col6" >-0.268003</td>
#       <td id="T_53852_row2_col7" class="data row2 col7" >0.036194</td>
#       <td id="T_53852_row2_col8" class="data row2 col8" >0.730940</td>
#     </tr>
#     <tr>
#       <th id="T_53852_level0_row3" class="row_heading level0 row3" >RAScore_pred_proba</th>
#       <td id="T_53852_row3_col0" class="data row3 col0" >0.085952</td>
#       <td id="T_53852_row3_col1" class="data row3 col1" >-0.178248</td>
#       <td id="T_53852_row3_col2" class="data row3 col2" >-0.043068</td>
#       <td id="T_53852_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_53852_row3_col4" class="data row3 col4" >-0.129451</td>
#       <td id="T_53852_row3_col5" class="data row3 col5" >0.228976</td>
#       <td id="T_53852_row3_col6" class="data row3 col6" >0.063765</td>
#       <td id="T_53852_row3_col7" class="data row3 col7" >0.267895</td>
#       <td id="T_53852_row3_col8" class="data row3 col8" >-0.020492</td>
#     </tr>
#     <tr>
#       <th id="T_53852_level0_row4" class="row_heading level0 row4" >Docking score</th>
#       <td id="T_53852_row4_col0" class="data row4 col0" >-0.200337</td>
#       <td id="T_53852_row4_col1" class="data row4 col1" >0.184621</td>
#       <td id="T_53852_row4_col2" class="data row4 col2" >0.286762</td>
#       <td id="T_53852_row4_col3" class="data row4 col3" >-0.129451</td>
#       <td id="T_53852_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_53852_row4_col5" class="data row4 col5" >-0.289770</td>
#       <td id="T_53852_row4_col6" class="data row4 col6" >0.126697</td>
#       <td id="T_53852_row4_col7" class="data row4 col7" >-0.365013</td>
#       <td id="T_53852_row4_col8" class="data row4 col8" >0.121079</td>

# %% [markdown]
# ## Random Forest Classification

# %%
enc = OneHotEncoder(handle_unknown='ignore')

# %%
enc.fit_transform(y)
# Out:
# <643x4 sparse matrix of type '<class 'numpy.float64'>'
# 	with 643 stored elements in Compressed Sparse Row format>

# %%
X_train, X_test, y_train, y_test = train_test_split(X_normalized, y, test_size=.2, random_state=1)

# %%
len(X_train)
# Out:
# 514

# %%
len(X_test)
# Out:
# 129

# %%
rf = RandomForestClassifier(n_estimators=500,
                            class_weight='balanced',
                            random_state=1)

rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', n_estimators=500,
#                        random_state=1)

# %%
y_pred = rf.predict(X_test)

# %%
precision = precision_score(y_pred, y_test, average='micro')

print(f'Precision score: {precision}')

print(classification_report(y_test, y_pred))
# Out:
# Precision score: 0.937984496124031
#               precision    recall  f1-score   support
#
#        coati       1.00      0.62      0.76        13
#         crem       0.91      0.98      0.94        41
#     reinvent       0.91      0.94      0.93        34
#         safe       0.98      1.00      0.99        41
#
#     accuracy                           0.94       129
#    macro avg       0.95      0.88      0.90       129
# weighted avg       0.94      0.94      0.93       129

# %%
weights = rf.feature_importances_
vars = X_normalized.columns

d = {'vars': vars, 'weights': weights}

rf_features = pd.DataFrame(data=d).sort_values(['weights'], ascending=False, ignore_index=True)

rf_features[:25]
# Out:
#                        vars   weights
# 0                desc_Bertz  0.227972
# 1   Weighted IFP Similarity  0.176361
# 2                  desc_QED  0.157649
# 3             Docking score  0.102627
# 4                      rmsd  0.097127
# 5       desc_NumHeteroatoms  0.091666
# 6  interaction weight ratio  0.085005
# 7        RAScore_pred_proba  0.061592
