# %% [markdown]
# # Visualizing Distributions of Generated Molecules

# %%
import os
print('Current conda environment:', os.environ['CONDA_DEFAULT_ENV'])

import warnings
warnings.filterwarnings('ignore')

import random
random.seed(42)
# Out:
# Current conda environment: reinvent4

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler

from rdkit import Chem
from rdkit.Chem import AllChem

sns.set(rc = {'figure.figsize':(15,8)})

# %%
df = pd.read_csv('dataframe.csv')

# %%
df.head()
# Out:
#    Unnamed: 0            SMILES     Input_SMILES  Tanimoto       NLL  \
# 0           0  c1ncc2c(n1)CCNC2  c1ncc2c(n1)NCC2  0.500000  2.699815
# 1           2    CC1CNc2ncncc21  c1ncc2c(n1)NCC2  0.435897  3.346807
# 2           5  c1ncc2[nH]cnc2n1  c1ncc2c(n1)NCC2  0.317073  3.952339
# 3           6  Cc1ncc2c(n1)NCC2  c1ncc2c(n1)NCC2  0.513514  4.039842
# 4           8   c1ncc2c(n1)NCC2  c1ncc2c(n1)NCC2  1.000000  4.296648
#
#                     ring_systems          min_ring  min_freq     Name  Success
# 0   [('c1ncc2c(n1)CCNC2', 1401)]  c1ncc2c(n1)CCNC2      1401  MOL0000    False
# 1     [('c1ncc2c(n1)NCC2', 814)]   c1ncc2c(n1)NCC2       814  MOL0001     True
# 2  [('c1ncc2[nH]cnc2n1', 24411)]  c1ncc2[nH]cnc2n1     24411  MOL0002     True
# 3     [('c1ncc2c(n1)NCC2', 814)]   c1ncc2c(n1)NCC2       814  MOL0003    False
# 4     [('c1ncc2c(n1)NCC2', 814)]   c1ncc2c(n1)NCC2       814  MOL0004     True

# %%
smiles = df['SMILES'].to_numpy()

# %%
mols = [Chem.MolFromSmiles(smile) for smile in smiles]

# %%
fpgen = AllChem.GetMorganGenerator()

# %%
fingerprints = np.array([fpgen.GetFingerprint(mol).ToList() for mol in mols])

# %%
X = fingerprints

pca = PCA(n_components=3, random_state=0)
pca_fps = pca.fit_transform(X)

# %%
df['PC1'], df['PC2'], df['PC3'] = pca_fps.T[0], pca_fps.T[1], pca_fps.T[2]

# %%
success = df[df['Success']]
failed = df[~df['Success']]

# %%
fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(16,8))

ax.scatter(success['PC1'], success['PC2'], s=5, c='midnightblue', label='Success')
ax.scatter(failed['PC1'], failed['PC2'], s=5, c='tomato', label='Failed')

ax.legend()

fig.suptitle('Comparison of Pre- and Post-Pipeline Distributions');

# %% [markdown]
# ### 3D PCA

# %%
f = sns.pairplot(df,
                 hue='Success',
                 vars=['PC1', 'PC2', 'PC3'],
                 palette=['tomato', 'midnightblue'],
                 aspect=2,
                 plot_kws=dict(s=10))

f.fig.suptitle('Pairwise Principle Component Plots', fontsize=18, y=1.04);

# %% [markdown]
# ### t-SNE w/ PCA preprocessing

# %%
p = 100

pca_model = PCA(n_components=30, random_state=0)
tsne_model = TSNE(n_components=2, random_state=0, perplexity=p, n_iter=5000)
tsne_fps = tsne_model.fit_transform(pca_model.fit_transform(X))

# %%
df['TSNE1'] = tsne_fps.T[0]
df['TSNE2'] = tsne_fps.T[1]

# %%
f = sns.pairplot(df,
                 hue='Success',
                 vars=['TSNE1', 'TSNE2'],
                 palette=['tomato', 'midnightblue'],
                 aspect=2,
                 plot_kws=dict(s=10))

f.fig.suptitle('t-SNE components ($p=5$)', y=1.06)
# Out:
# Text(0.5, 1.06, 't-SNE components ($p=5$)')

# %%
p = 7

pca_model = PCA(n_components=30, random_state=0)
tsne_model = TSNE(n_components=2, random_state=0, perplexity=p, n_iter=5000)
tsne_fps = tsne_model.fit_transform(pca_model.fit_transform(X))

# %%
df['TSNE1'] = tsne_fps.T[0]
df['TSNE2'] = tsne_fps.T[1]

# %%
f = sns.pairplot(df,
                 hue='Success',
                 vars=['TSNE1', 'TSNE2'],
                 palette=['tomato', 'midnightblue'],
                 aspect=2,
                 plot_kws=dict(s=10))

f.fig.suptitle('t-SNE components ($p=7$)', y=1.06)
# Out:
# Text(0.5, 1.06, 't-SNE components ($p=7$)')

# %%
p = 10

pca_model = PCA(n_components=30, random_state=0)
tsne_model = TSNE(n_components=2, random_state=0, perplexity=p, n_iter=5000)
tsne_fps = tsne_model.fit_transform(pca_model.fit_transform(X))

df['TSNE1'] = tsne_fps.T[0]
df['TSNE2'] = tsne_fps.T[1]

f = sns.pairplot(df,
                 hue='Success',
                 vars=['TSNE1', 'TSNE2'],
                 palette=['tomato', 'midnightblue'],
                 aspect=2,
                 plot_kws=dict(s=10))

f.fig.suptitle('t-SNE components ($p=10$)', y=1.06);

# %% [markdown]
# ### PCA with `StandardScaler()`

# %%
scaler = StandardScaler()

# %%
X_scaled = scaler.fit_transform(X)

# %%
pca = PCA(n_components=3, random_state=0)
pca_fps = pca.fit_transform(X_scaled)

# %%
df['PC1'], df['PC2'], df['PC3'] = pca_fps.T[0], pca_fps.T[1], pca_fps.T[2]

# %%
f = sns.pairplot(df,
                 hue='Success',
                 vars=['PC1', 'PC2', 'PC3'],
                 palette=['tomato', 'midnightblue'],
                 aspect=2,
                 plot_kws=dict(s=10))

f.fig.suptitle('Pairwise Principle Component Plots', fontsize=18, y=1.04);
